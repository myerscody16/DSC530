# %%
'''Exercise 2-1 response: The summary statistics that I would use is the mean pregnancy length for both first born children
and for subsequent children. As we read on page 23, the mean for the length of first pregnancies is 38.601 and the mean for 
the other pregnancies is 38.523. That small difference in mean's show that there is very little, if any truth to the statement 
"First born children always have a longer pregnancy.". 
'''
# Out:
# 'Exercise 2-1 response: The summary statistics that I would use is the mean pregnancy length for both first born children\nand for subsequent children. As we read on page 23, the mean for the length of first pregnancies is 38.601 and the mean for \nthe other pregnancies is 38.523. That small difference in mean\'s show that there is very little, if any truth to the statement \n"First born children always have a longer pregnancy.". \n'

# %%
from __future__ import print_function

import sys
from operator import itemgetter

import math
import first
import thinkstats2
import nsfg

# %%
def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean()
    
    var1 = group1.var()
    var2 = group2.var()
    n1, n2 = len(group1), len(group2)
    
    pooled_var = (n1 * var1 + n2 * var2)/(n1 + n2)
    d = diff / math.sqrt(pooled_var)
    return d

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN  ...           0           0        0
# 1       NaN       1.0       NaN  ...           0           0        0
# 2       NaN       3.0       5.0  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %%
firstPreg, subsequentPreg = [x for _, x in preg.groupby(preg["birthord"] > 1)]

# %%
firstPreg.head()
# Out:
#     caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0        1         1        NaN        NaN       NaN       NaN       6.0
# 2        2         1        NaN        NaN       NaN       NaN       5.0
# 5        6         1        NaN        NaN       NaN       NaN       6.0
# 8        7         1        NaN        NaN       NaN       NaN       5.0
# 10      12         1        NaN        NaN       NaN       NaN       5.0
#
#     pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0        NaN       1.0       NaN  ...           0           0        0
# 2        NaN       3.0       5.0  ...           0           0        0
# 5        NaN       1.0       NaN  ...           0           0        0
# 8        NaN       1.0       NaN  ...           0           0        0
# 10       NaN       1.0       NaN  ...           0           0        0
#
#         basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %%
subsequentPreg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
# 6       6         2        NaN        NaN       NaN       NaN       6.0
# 7       6         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 1       NaN       1.0       NaN  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
# 6       NaN       1.0       NaN  ...           0           0        0
# 7       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %%
firstPreg["totalwgt_lb"].mean()
# Out:
# 7.201094430437772

# %%
subsequentPreg["totalwgt_lb"].mean()
# Out:
# 7.325855614973262

# %%
CohenEffectSize(firstPreg["totalwgt_lb"], subsequentPreg["totalwgt_lb"])
# Out:
# -0.08839280497623067

# %%
'''Based upon the calculations of the means of the two weights and the Cohen Effect Size, I can confirm that there is
very little impact on the weight of a baby based upon their birth order. In regards to how this compares to the pregnancy
length, we see a similar result. There is little to no effect on the either the weight of the baby or the length of the 
pregnancy.'''
# Out:
# 'Based upon the calculations of the means of the two weights and the Cohen Effect Size, I can confirm that there is\nvery little impact on the weight of a baby based upon their birth order. In regards to how this compares to the pregnancy\nlength, we see a similar result. There is little to no effect on the either the weight of the baby or the length of the \npregnancy.'
